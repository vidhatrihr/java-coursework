// %%
String name = "vidhatri";
System.out.println(name);

int age = 21;
System.out.println(age);
// Out:
// vidhatri
// 21

// %%
String[] animals = new String[] {"cat","dog","lion","tiger"};
System.out.println(Arrays.toString(animals));

String[] colors = new String[5];
colors[0] = "red";
colors[1] = "black";
colors[4] = "blue";
System.out.println(Arrays.toString(colors));
// Out:
// [cat, dog, lion, tiger]
// [red, black, null, null, blue]

// %%
for (int i=0; i < colors.length; i++) {
  System.out.println(String.format("%d th color is %s", i, colors[i]));
}

for (String animal : animals) {
  System.out.println(animal);
}
// Out:
// 0 th color is red
// 1 th color is black
// 2 th color is null
// 3 th color is null
// 4 th color is blue
// cat
// dog
// lion
// tiger

// %%
class Student {
  String name;
  int age;
  int grade;

  // constructor
  Student(String name, int age, int grade) {
    this.name = name;
    this.age = age;
    this.grade = grade;
  }

  void introduce() {
    System.out.println(String.format("I am %s, %d years old and I am studying in %d", name, age, grade));
  }

  void demo() {
    System.out.println("Hello " + name);
  }
}

Student vidu = new Student("vidu", 21, 10);
vidu.introduce();
vidu.demo();
// Out:
// I am vidu, 21 years old and I am studying in 10
// Hello vidu

// %%
class Human {
  String name;
  int age;

  Human(String name, int age) {
    this.name = name;
    this.age = age;
  }

  void sleep() {
    System.out.println("Human is sleeping");
  }
}

class Employee extends Human {
  int salary;

  Employee(String name, int age , int salary) {
    super(name, age);
    this.salary = salary;
  }

  void sleep() {
    super.sleep();
    System.out.println("Employee is sleeping");
  }
}

Employee vidu = new Employee("vidu", 20, 20000);
vidu.sleep()
// Out:
// Human is sleeping
// Employee is sleeping

// %%
class Doctor{
  String name;
  int salary;
  String[] fruits;

  Doctor(String name, int salary, String[] fruits) {
    this.name = name;
    this.salary = salary;
    this.fruits = fruits;
  }

  Doctor(Doctor doctor) {
    this.name = doctor.name;
    this.salary = doctor.salary * 2;
    this.fruits = doctor.fruits.clone();
  }
}

Doctor paru = new Doctor("paru", 20000, new String[]{"apple", "banana", "kiwi"});
Doctor somebody = new Doctor(paru);

System.out.println(paru.fruits.hashCode());
System.out.println(somebody.fruits.hashCode());
// Out:
// 415839764
// 415839764

// %%
String[] fruits1 = new String[]{"apple", "kiwi"};
String[] fruits2 = new String[]{"apple", "kiwi"};
String[] fruits3 = fruits1;


System.out.println(fruits1 == fruits3);
System.out.println(fruits1.hashCode());
System.out.println(fruits3.hashCode());

fruits1[0] = "mango";
fruits3[0];
// Out:
// true
// 336263510
// 336263510
// mango

// %%
class Human {
  public String name;
  private int age;
}

class Girl extends Human {
  void intro() {
    System.out.println(name);
  }
}

new Girl().intro();
// Out:
// null

// %%
Map<String, Integer> map = new LinkedHashMap<>();
String name  = "";
int std = 0;

map.put(name = "vidu", std = 10);
System.out.println(map);
map.containsKey("vidu");
// Out:
// {vidu=10}
// true

// %%
int num = 10;

map.put("rahul", 10+num);
System.out.println(map);
// Out:
// {vidu=10, rahul=20}
